# %% [markdown]
# # BUILD APK - CONTROL DE OBRA
# Sigue las celdas UNA POR UNA en orden. No te saltes ninguna.

# %% [markdown]
# ## PASO 1: Montar Google Drive (opcional)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## PASO 2: Subir tu proyecto ZIP

# %%
from google.colab import files
import zipfile, os

print("👉 Selecciona el archivo acobamba_app.zip")
uploaded = files.upload()
zip_name = list(uploaded.keys())[0]
print(f"Subido: {zip_name}")

# Extraer
with zipfile.ZipFile(zip_name, 'r') as z:
    z.extractall('/content/')
print('✅ Extraido correctamente')

# %cd /content/acobamba_app
print('📁 Directorio:', os.getcwd())
# !ls -la

# %% [markdown]
# ## PASO 3: Instalar Python 3.11
# **IMPORTANTE:** Despues de esta celda, el entorno se reinicia. Espera a que termine.

# %%
print('Instalando Python 3.11 via condacolab...')
# !pip install -q condacolab
import condacolab
condacolab.install()
print('✅ Python listo')
# !python --version

# %% [markdown]
# ## PASO 4: Subir el ZIP otra vez (el entorno se reinicio)

# %%
from google.colab import files
import zipfile, os

print("👉 Selecciona el mismo archivo acobamba_app.zip")
uploaded = files.upload()
zip_name = list(uploaded.keys())[0]

with zipfile.ZipFile(zip_name, 'r') as z:
    z.extractall('/content/')
print('✅ Extraido')

# %cd /content/acobamba_app
print('📁 Directorio:', os.getcwd())
# !python --version

# %% [markdown]
# ## PASO 5: Instalar dependencias de compilacion

# %%
print('Dependencias del sistema...')
# !apt-get update -qq
# !apt-get install -y -qq git zip unzip openjdk-17-jdk autoconf libtool pkg-config zlib1g-dev libncurses5-dev libncursesw5-dev libtinfo5 cmake libffi-dev libssl-dev libltdl-dev 2>&1 | tail -3
print('✅ Sistema listo')

print('Cython y Buildozer...')
# !pip install -q --upgrade Cython==0.29.36 virtualenv buildozer
print('✅ Buildozer listo')

# Limpiar cache de intentos anteriores
# !rm -rf .buildozer/android/platform/build-arm64-v8a
print('🧹 Cache limpiado')

# %% [markdown]
# ## PASO 6: COMPILAR APK
# ⏱ Primera vez: 20-40 min. Siguientes: 5-10 min.

# %%
# !buildozer android debug 2>&1

# %% [markdown]
# ## PASO 7: Descargar APK

# %%
import glob
# !ls -lh bin/
apk = glob.glob('bin/*.apk')
if apk:
    files.download(apk[0])
    print('✅ APK descargandose...')
else:
    print('❌ No se encontro APK en bin/')

# %% [markdown]
# ## ✅ LISTO
# Instala el APK en tu celular.
